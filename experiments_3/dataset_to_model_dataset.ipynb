# %%
import pandas as pd

# %%
from glob import glob
from pathlib import Path

# %%
from joblib import Parallel, delayed

# %%
files = glob('./data/ecg_preprocessed/*.csv')

# %%
def to_model_dataset(file):
    df = pd.read_csv(file)

    baseline = ['Sitting', 'Recov1', 'Recov2', 'Recov3', 'Recov4', 'Recov5', 'Recov6']
    mental_stress = ['TA', 'SSST_Sing_countdown', 'Pasat', 'Raven', 'TA_repeat', 'Pasat_repeat']
    high_physical_stress = ['Treadmill1', 'Treadmill2', 'Treadmill3', 'Treadmill4', 'Walking_fast_pace', 'Cycling', 'stairs_up_and_down']
    moderate_physical_stress = ['Walking_own_pace', 'Dishes', 'Vacuum']
    low_physical_stress = ['Standing', 'Lying_supine', 'Recov_standing']

    df['label'] = -1
    df['label'] = df['label'].astype(int)

    for category in baseline:
        df.loc[df['category'] == category, 'label'] = 0
    for category in mental_stress:
        df.loc[df['category'] == category, 'label'] =-1
    for category in high_physical_stress:
        df.loc[df['category'] == category, 'label'] = 1
    for category in moderate_physical_stress:
        df.loc[df['category'] == category, 'label'] = -1
    for category in low_physical_stress:
        df.loc[df['category'] == category, 'label'] = -1

    df = df[df.label != -1]
    df = df[['ECG_Clean', 'label']]
    df = df.rename(columns={'ECG_Clean': 'signal'})

    df.to_csv(f'./data/ecg_better_model_physical_activity/{Path(file).name}', index=False)

# %%
# for file in files:
#     to_model_dataset(file)

# %%
Parallel(n_jobs=8)(delayed(to_model_dataset)(file) for file in files)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
