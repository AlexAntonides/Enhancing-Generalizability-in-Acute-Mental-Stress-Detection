# %%
import datasets

# %%
dataset = datasets.load_dataset(
    'csv', 
    data_files='./data/ecg_unprocessed/30100.csv',
    features=datasets.Features({
        'timestamp': datasets.Value('string'),
        'signal': datasets.Value('float64'),
        'category': datasets.Value('string'),
    })
)['train']

# %%
import pandas as pd

# %%
data = pd.read_pickle(f'./data/wesad/S2/S2.pkl')
wesad = pd.DataFrame({
    'signal': data['signal']['chest']['ECG'].flatten(),
    'label': data['label']
})

# %%
import neurokit2 as nk

# %%
sample = dataset[0:0+60 * 1000]

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.min(wesad['signal']), np.max(wesad['signal']), np.mean(wesad['signal']), np.std(wesad['signal'])
# Out:
# (-1.499542236328125,
#  1.4993133544921875,
#  0.001212244628837402,
#  0.1540772961529594)

# %%
np.min(dataset['signal']),np.max(dataset['signal']), np.mean(dataset['signal']), np.std(dataset['signal'])
# Out:
# (-0.0054941634241245,
#  0.0055002670328831,
#  0.00012634930920621908,
#  0.0003184506137697464)

# %%
plt.plot(sample['signal'][3736-500:3736+500])
